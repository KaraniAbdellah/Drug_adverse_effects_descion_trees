# %% [markdown]
# ## Problem Description

# %%
# GITHUB: https://github.com/TeamRocketKP/Drug_adverse_effects
# --> fork it and add execl file

# In this problem We want to see the ADRs of medicals to clients.
# and ADRs (الآثار الجانبية للأدوية) can range from mild symptoms, such as nausea or dizziness, to more serious or life-threatening events, such as anaphylaxis(severe allergic reaction) or organ damage.

# تتراوح الأعراض من أعراض خفيفة
# مثل الغثيان أو الدوار، إلى أحداث أكثر خطورة أو تهدد الحياة
# مثل الحساسية المفرطة (رد فعل تحسسي شديد) أو تلف الأعضاء.


# DataSet From: https://open.fda.gov/apis/


# Challange: data from api to execl file
# --> https://api.fda.gov/drug/event.json?limit=100


# tasks
# --> Simple Script that get data from API and Prepare it and Store in MYSQL Database
# --> Exploite the Data and Start
# --> Make Web Application (With DataSet and Look At Blog)
